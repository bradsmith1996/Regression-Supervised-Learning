# %%
# NOTE: Only run this once to set the directory!!! This could probably be done better but oh well
import os
os.chdir("..")

# %%
# %run training.py \
     --dataset-path \
     datasets/mobile_KMeans_n_clusters_2max_iter_10000tol_1e-08n_init_50 \
     --output-path \
     output/mobile_KMeans_n_clusters_2max_iter_10000tol_1e-08n_init_50/neural_network \
     --grid-cv-search-dict="{'kerasclassifier__learning_rate': [0.0005, 0.001, 0.005], 'kerasclassifier__batch_size': [16, 32, 64, 128], 'kerasclassifier__hidden_dim': [16, 32, 64, 128], 'kerasclassifier__hidden_count': [2,3,4,5]}"
# Out:
# Created output folder: output/mobile_KMeans_n_clusters_2max_iter_10000tol_1e-08n_init_50/neural_network/mobile_KMeans_n_clusters_2max_iter_10000tol_1e-08n_init_50/grid_search_hd64_hc3_ne20_bs32_lr_0.01
# Fitting 10 folds for each of 192 candidates, totalling 1920 fits
# /Users/brad/School/gt/spring2022/cs7641/CS7641-UnsupervisedLearning/training.py:278: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead.
#   KerasClassifier(build_fn=create_model,
# 2022-03-26 22:51:15.148229: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# %run training.py \
     --dataset-path \
     datasets/mobile_KMeans_n_clusters_2max_iter_10000tol_1e-08n_init_50 \
     --output-path \
     output/mobile_KMeans_n_clusters_2max_iter_10000tol_1e-08n_init_50/neural_network \
     --batch-size 128 \
     --hidden-layer-count 3 \
     --hidden-dim 16 \
     --learning-rate 0.005
# Out:
# Created output folder: output/mobile_KMeans_n_clusters_2max_iter_10000tol_1e-08n_init_50/neural_network/mobile_KMeans_n_clusters_2max_iter_10000tol_1e-08n_init_50/training_hd16_hc3_ne20_bs128_lr_0.005
# /Users/brad/School/gt/spring2022/cs7641/CS7641-UnsupervisedLearning/training.py:278: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead.
#   KerasClassifier(build_fn=create_model,
# 2022-03-27 07:16:04.176673: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
