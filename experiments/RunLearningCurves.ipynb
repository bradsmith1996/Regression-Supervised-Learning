# %%
# NOTE: Only run this once to set the directory!!! This could probably be done better but oh well
import os
os.chdir("..")

# %%
# Run test for selected files
# %run training_regression.py \
--dataset-path \
datasets/aluminum_forced_flow \
--output-path \
output \
--num-outputs \
2 \
--algorithm-inputs="{'hidden_count':4,'hidden_dim':128,'learning_rate':0.001,'epochs':50,'batch_size':32}"
# Out:
# Created output folder: output/aluminum_forced_flow/neural_network/hidden_count_4hidden_dim_128learning_rate_0.001epochs_50batch_size_32
# 2022-05-05 17:50:30.547241: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-05 17:50:30.547251: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-05 17:50:30.547257: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-05 17:50:30.547251: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-05 17:50:30.547241: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-05 17:50:30.547255: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-05 17:50:30.547254: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-05 17:50:30.547257: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Maximum Validation Accuracy Samples = 124 (Negative Mean Squared Error=-4.2337072660720905)
#
# Validation Accuracy Over All Samples = 161 (Negative Mean Squared Error=-37.30026390259478)
# 2022-05-05 17:50:39.949896: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Output 0 Mean Abs Percent Error: 0.649129608592811
# Output 1 Mean Abs Percent Error: 0.9953670791961248
# Training time: 5.495587110519409
# 2022-05-05 17:50:45.968236: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: ram:///var/folders/xm/ztz51scj7nzdd7nbtsmyk4rc0000gn/T/tmpobgelc3o/assets

# %%
# Run test for selected files
# %run training_regression.py \
--dataset-path \
datasets/aluminum_forced_flow \
--output-path \
output \
--num-outputs \
2 \
--algorithm-inputs="{'hidden_count':4,'hidden_dim':128,'learning_rate':0.1,'epochs':50,'batch_size':32}"
# Out:
# Created output folder: output/aluminum_forced_flow/neural_network/hidden_count_4hidden_dim_128learning_rate_0.1epochs_50batch_size_32
# Maximum Validation Accuracy Samples = 124 (Negative Mean Squared Error=-28.060220127635926)
#
# Validation Accuracy Over All Samples = 161 (Negative Mean Squared Error=-63.97406630904423)
# Output 0 Mean Abs Percent Error: 0.554146898429601
# Output 1 Mean Abs Percent Error: 5.427817439394406
# Training time: 5.640661954879761
# INFO:tensorflow:Assets written to: ram:///var/folders/xm/ztz51scj7nzdd7nbtsmyk4rc0000gn/T/tmpp_5pkd3w/assets
