# %%
# NOTE: Only run this once to set the directory!!! This could probably be done better but oh well
import os
os.chdir("..")

# %%
# Run test for selected files
# %run training_regression.py \
--dataset-path \
datasets/aluminum_forced_flow \
--output-path \
output \
--num-outputs \
2 \
--algorithm-inputs="{'hidden_count':4,'hidden_dim':128,'learning_rate':0.001,'epochs':50,'batch_size':32}" \
--test
# Out:
# Created output folder: output/aluminum_forced_flow/neural_network/hidden_count_4hidden_dim_128learning_rate_0.001epochs_50batch_size_32
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14fb18400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %%
# Run test for selected files
# %run training_regression.py \
--dataset-path \
datasets/aluminum_forced_flow \
--output-path \
output \
--num-outputs \
2 \
--algorithm-inputs="{'hidden_count':4,'hidden_dim':128,'learning_rate':0.1,'epochs':50,'batch_size':32}"
# Out:
# Created output folder: output/aluminum_forced_flow/neural_network/hidden_count_4hidden_dim_128learning_rate_0.1epochs_50batch_size_32
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14c300180> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...
